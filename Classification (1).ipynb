# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
from sklearn import tree

# %%
df=pd.read_csv("FinalDataset_phase2.csv")
print(df.head())
# Out:
#        Id  Genetics  Hormonal Changes Medical Conditions  \
# 0  148393         0                 0             Eczema
# 1  155074         0                 0         Dermatosis
# 2  118261         1                 1           Ringworm
# 3  111915         0                 0          Psoriasis
# 4  139661         1                 0          Psoriasis
#
#   Medications & Treatments Nutritional Deficiencies     Stress      Age  \
# 0              Antibiotics      Magnesium deficiency      High  0.78125
# 1         Antifungal Cream        Protein deficiency  Moderate  0.25000
# 2              Antibiotics        Biotin Deficiency   Moderate  0.87500
# 3                 Accutane           Iron deficiency  Moderate  0.37500
# 4              Antibiotics      Magnesium deficiency       Low  0.59375
#
#   Poor Hair Care Habits  Environmental Factors Smoking Weight Loss   \
# 0                    Yes                   Yes      No           No
# 1                    Yes                   Yes      No          Yes
# 2                    Yes                   Yes      No           No
# 3                     No                   Yes     Yes           No
# 4                     No                   Yes      No          Yes
#
#    Hair Loss          Bald  discretized_Age
# 0          0     Hair Loss                2
# 1          0     Hair Loss                0
# 2          0     Hair Loss                2
# 3          1  No Hair Loss                1
# 4          1  No Hair Loss                1

# %%
label_encoder = LabelEncoder()
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = label_encoder.fit_transform(df[col])

# %%
X = df.drop(columns=["Genetics"])  
y = df["Genetics"]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
print(cm)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No', 'Yes'])
disp.plot(cmap=plt.cm.Reds)
plt.show()
# Out:
# Accuracy: 0.5308641975308642
# [[37 38]
#  [38 49]]

# %%
# Accuracy of prediction with test size 0.2 = 53% (highest accuracy rate)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
print(cm)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No', 'Yes'])
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# Accuracy: 0.5432098765432098
# [[59 60]
#  [51 73]]

# %%
# Accuracy of prediction with test size 0.3 = 54% (middle accuracy rate)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
print(cm)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No', 'Yes'])
disp.plot(cmap=plt.cm.Greens)
plt.show()
# Out:
# Accuracy: 0.5061728395061729
# [[74 80]
#  [80 90]]

# %%
# Accuracy of prediction with test size 0.4 = 50% (lowest accuracy rate)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
plt.figure(figsize=(20, 10))
plot_tree(clf, feature_names=X.columns, class_names=['No', 'Yes'], filled=True)
plt.show()
# Out:
# Accuracy: 0.5432098765432098

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
plt.figure(figsize=(20, 10))
plot_tree(clf, feature_names=X.columns, class_names=['No', 'Yes'], filled=True)
plt.show()
# Out:
# Accuracy: 0.5102880658436214

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
plt.figure(figsize=(20, 10))
plot_tree(clf, feature_names=X.columns, class_names=['No', 'Yes'], filled=True)
plt.show()
# Out:
# Accuracy: 0.5123456790123457

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
clf = DecisionTreeClassifier(criterion="entropy")
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
plt.figure(figsize=(20, 10))
plot_tree(clf, feature_names=X.columns, class_names=['No', 'Yes'], filled=True)
plt.show()
# Out:
# Accuracy: 0.5

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
clf = DecisionTreeClassifier(criterion="entropy")
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
plt.figure(figsize=(20, 10))
plot_tree(clf, feature_names=X.columns, class_names=['No', 'Yes'], filled=True)
plt.show()
# Out:
# Accuracy: 0.5020576131687243

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)
clf = DecisionTreeClassifier(criterion="entropy")
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
plt.figure(figsize=(20, 10))
plot_tree(clf, feature_names=X.columns, class_names=['No', 'Yes'], filled=True)
plt.show()
# Out:
# Accuracy: 0.49382716049382713

# %%
partition_sizes = [0.2, 0.3, 0.4]

criterions = ["entropy", "gini"]

results = {}

for size in partition_sizes:
    for criterion in criterions:
        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1-size, random_state=42)

        clf = DecisionTreeClassifier(criterion=criterion, random_state=42)
        
        clf.fit(X_train, y_train)
        
        y_pred = clf.predict(X_test)
        
        accuracy = accuracy_score(y_test, y_pred)
        
        results[(size, criterion)] = accuracy

for (size, criterion), accuracy in results.items():
    print(f"Partition Size: {size}, Criterion: {criterion}, Accuracy: {accuracy}")

sizes_entropy = [size for size, criterion in results if criterion == "entropy"]
accuracies_entropy = [results[(size, "entropy")] for size in sizes_entropy]
sizes_gini = [size for size, criterion in results if criterion == "gini"]
accuracies_gini = [results[(size, "gini")] for size in sizes_gini]

plt.figure(figsize=(10, 6))
plt.plot(sizes_entropy, accuracies_entropy, marker='o', label='Entropy')
plt.plot(sizes_gini, accuracies_gini, marker='o', label='Gini')
plt.title('Accuracy vs Partition Size')
plt.xlabel('Partition Size')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Partition Size: 0.2, Criterion: entropy, Accuracy: 0.5
# Partition Size: 0.2, Criterion: gini, Accuracy: 0.49691358024691357
# Partition Size: 0.3, Criterion: entropy, Accuracy: 0.5026455026455027
# Partition Size: 0.3, Criterion: gini, Accuracy: 0.47442680776014107
# Partition Size: 0.4, Criterion: entropy, Accuracy: 0.5452674897119342
# Partition Size: 0.4, Criterion: gini, Accuracy: 0.5020576131687243

# %%
# Using Entropy the accuracy generally increases as the partition size increases
# Using Gini the accuracy decreases when the partition size lies between 0.200 to 0.300 and increases from partition size 0.300 and above
